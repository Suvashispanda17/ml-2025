# %%
import numpy as np

# %%
def grad(x,y):
    m_curr = b_curr =0
    iterations =1000
    n = len(x)
    learning_rate = 0.008

    for i in  range (iterations):
        y_predict = m_curr * x+ b_curr
        cost = (1/n) * sum([val**2 for val in(y- y_predict)])
        md = -(2/n) * sum(x*(y- y_predict))
        bd = md = -(2/n) * sum(y- y_predict)
    
        m_curr - m_curr - learning_rate * md
        b_curr - b_curr - learning_rate * bd
    
        print("m{} , b{} ,cost{},iterations{}".format(m_curr,b_curr,cost,i))

# %%
x= np.array([1,2,3,4,5])
y = np.array([6,7,8,9,10])
print(grad(x,y))
# Out:
# m0 , b0 ,cost66.0,iterations0
# m0 , b0 ,cost66.0,iterations1
# m0 , b0 ,cost66.0,iterations2
# m0 , b0 ,cost66.0,iterations3
# m0 , b0 ,cost66.0,iterations4
# m0 , b0 ,cost66.0,iterations5
# m0 , b0 ,cost66.0,iterations6
# m0 , b0 ,cost66.0,iterations7
# m0 , b0 ,cost66.0,iterations8
# m0 , b0 ,cost66.0,iterations9
# m0 , b0 ,cost66.0,iterations10
# m0 , b0 ,cost66.0,iterations11
# m0 , b0 ,cost66.0,iterations12
# m0 , b0 ,cost66.0,iterations13
# m0 , b0 ,cost66.0,iterations14
# m0 , b0 ,cost66.0,iterations15
# m0 , b0 ,cost66.0,iterations16
# m0 , b0 ,cost66.0,iterations17
# m0 , b0 ,cost66.0,iterations18
# m0 , b0 ,cost66.0,iterations19
# m0 , b0 ,cost66.0,iterations20
# m0 , b0 ,cost66.0,iterations21
# m0 , b0 ,cost66.0,iterations22
# m0 , b0 ,cost66.0,iterations23
# m0 , b0 ,cost66.0,iterations24
# m0 , b0 ,cost66.0,iterations25
# m0 , b0 ,cost66.0,iterations26
# m0 , b0 ,cost66.0,iterations27
# m0 , b0 ,cost66.0,iterations28
# m0 , b0 ,cost66.0,iterations29
# m0 , b0 ,cost66.0,iterations30
# m0 , b0 ,cost66.0,iterations31
# m0 , b0 ,cost66.0,iterations32
# m0 , b0 ,cost66.0,iterations33
# m0 , b0 ,cost66.0,iterations34
# m0 , b0 ,cost66.0,iterations35
# m0 , b0 ,cost66.0,iterations36
# m0 , b0 ,cost66.0,iterations37
# m0 , b0 ,cost66.0,iterations38
# m0 , b0 ,cost66.0,iterations39
# m0 , b0 ,cost66.0,iterations40
# m0 , b0 ,cost66.0,iterations41
# m0 , b0 ,cost66.0,iterations42
# m0 , b0 ,cost66.0,iterations43
# m0 , b0 ,cost66.0,iterations44
# m0 , b0 ,cost66.0,iterations45
# m0 , b0 ,cost66.0,iterations46
# m0 , b0 ,cost66.0,iterations47
# m0 , b0 ,cost66.0,iterations48
# m0 , b0 ,cost66.0,iterations49
# m0 , b0 ,cost66.0,iterations50
# m0 , b0 ,cost66.0,iterations51
# m0 , b0 ,cost66.0,iterations52
# m0 , b0 ,cost66.0,iterations53
# m0 , b0 ,cost66.0,iterations54
# m0 , b0 ,cost66.0,iterations55
# m0 , b0 ,cost66.0,iterations56
# m0 , b0 ,cost66.0,iterations57
# m0 , b0 ,cost66.0,iterations58
# m0 , b0 ,cost66.0,iterations59
# m0 , b0 ,cost66.0,iterations60
# m0 , b0 ,cost66.0,iterations61
# m0 , b0 ,cost66.0,iterations62
# m0 , b0 ,cost66.0,iterations63
# m0 , b0 ,cost66.0,iterations64
# m0 , b0 ,cost66.0,iterations65
# m0 , b0 ,cost66.0,iterations66
# m0 , b0 ,cost66.0,iterations67
# m0 , b0 ,cost66.0,iterations68
# m0 , b0 ,cost66.0,iterations69
# m0 , b0 ,cost66.0,iterations70
# m0 , b0 ,cost66.0,iterations71
# m0 , b0 ,cost66.0,iterations72
# m0 , b0 ,cost66.0,iterations73
# m0 , b0 ,cost66.0,iterations74
# m0 , b0 ,cost66.0,iterations75
# m0 , b0 ,cost66.0,iterations76
# m0 , b0 ,cost66.0,iterations77
# m0 , b0 ,cost66.0,iterations78
# m0 , b0 ,cost66.0,iterations79
# m0 , b0 ,cost66.0,iterations80
# m0 , b0 ,cost66.0,iterations81
# m0 , b0 ,cost66.0,iterations82
# m0 , b0 ,cost66.0,iterations83
# m0 , b0 ,cost66.0,iterations84
# m0 , b0 ,cost66.0,iterations85
# m0 , b0 ,cost66.0,iterations86
# m0 , b0 ,cost66.0,iterations87
# m0 , b0 ,cost66.0,iterations88
# m0 , b0 ,cost66.0,iterations89
# m0 , b0 ,cost66.0,iterations90
# m0 , b0 ,cost66.0,iterations91
# m0 , b0 ,cost66.0,iterations92
# m0 , b0 ,cost66.0,iterations93
# m0 , b0 ,cost66.0,iterations94
# m0 , b0 ,cost66.0,iterations95
# m0 , b0 ,cost66.0,iterations96
# m0 , b0 ,cost66.0,iterations97
# m0 , b0 ,cost66.0,iterations98
# m0 , b0 ,cost66.0,iterations99
# m0 , b0 ,cost66.0,iterations100
# m0 , b0 ,cost66.0,iterations101
# m0 , b0 ,cost66.0,iterations102
# m0 , b0 ,cost66.0,iterations103
# m0 , b0 ,cost66.0,iterations104
# m0 , b0 ,cost66.0,iterations105
# m0 , b0 ,cost66.0,iterations106
# m0 , b0 ,cost66.0,iterations107
# m0 , b0 ,cost66.0,iterations108
# m0 , b0 ,cost66.0,iterations109
# m0 , b0 ,cost66.0,iterations110
# m0 , b0 ,cost66.0,iterations111
# m0 , b0 ,cost66.0,iterations112
# m0 , b0 ,cost66.0,iterations113
# m0 , b0 ,cost66.0,iterations114
# m0 , b0 ,cost66.0,iterations115
# m0 , b0 ,cost66.0,iterations116
# m0 , b0 ,cost66.0,iterations117
# m0 , b0 ,cost66.0,iterations118
# m0 , b0 ,cost66.0,iterations119
# m0 , b0 ,cost66.0,iterations120
# m0 , b0 ,cost66.0,iterations121
# m0 , b0 ,cost66.0,iterations122
# m0 , b0 ,cost66.0,iterations123
# m0 , b0 ,cost66.0,iterations124
# m0 , b0 ,cost66.0,iterations125
# m0 , b0 ,cost66.0,iterations126
# m0 , b0 ,cost66.0,iterations127
# m0 , b0 ,cost66.0,iterations128
# m0 , b0 ,cost66.0,iterations129
# m0 , b0 ,cost66.0,iterations130
# m0 , b0 ,cost66.0,iterations131
# m0 , b0 ,cost66.0,iterations132
# m0 , b0 ,cost66.0,iterations133
# m0 , b0 ,cost66.0,iterations134
# m0 , b0 ,cost66.0,iterations135
# m0 , b0 ,cost66.0,iterations136
# m0 , b0 ,cost66.0,iterations137
# m0 , b0 ,cost66.0,iterations138
# m0 , b0 ,cost66.0,iterations139
# m0 , b0 ,cost66.0,iterations140
# m0 , b0 ,cost66.0,iterations141
# m0 , b0 ,cost66.0,iterations142
# m0 , b0 ,cost66.0,iterations143
# m0 , b0 ,cost66.0,iterations144
# m0 , b0 ,cost66.0,iterations145
# m0 , b0 ,cost66.0,iterations146
# m0 , b0 ,cost66.0,iterations147
# m0 , b0 ,cost66.0,iterations148
# m0 , b0 ,cost66.0,iterations149
# m0 , b0 ,cost66.0,iterations150
# m0 , b0 ,cost66.0,iterations151
# m0 , b0 ,cost66.0,iterations152
# m0 , b0 ,cost66.0,iterations153
# m0 , b0 ,cost66.0,iterations154
# m0 , b0 ,cost66.0,iterations155
# m0 , b0 ,cost66.0,iterations156
# m0 , b0 ,cost66.0,iterations157
# m0 , b0 ,cost66.0,iterations158
# m0 , b0 ,cost66.0,iterations159
# m0 , b0 ,cost66.0,iterations160
# m0 , b0 ,cost66.0,iterations161
# m0 , b0 ,cost66.0,iterations162
# m0 , b0 ,cost66.0,iterations163
# m0 , b0 ,cost66.0,iterations164
# m0 , b0 ,cost66.0,iterations165
# m0 , b0 ,cost66.0,iterations166
# m0 , b0 ,cost66.0,iterations167
# m0 , b0 ,cost66.0,iterations168
# m0 , b0 ,cost66.0,iterations169
# m0 , b0 ,cost66.0,iterations170
# m0 , b0 ,cost66.0,iterations171
# m0 , b0 ,cost66.0,iterations172
# m0 , b0 ,cost66.0,iterations173
# m0 , b0 ,cost66.0,iterations174
# m0 , b0 ,cost66.0,iterations175
# m0 , b0 ,cost66.0,iterations176
# m0 , b0 ,cost66.0,iterations177
# m0 , b0 ,cost66.0,iterations178
# m0 , b0 ,cost66.0,iterations179
# m0 , b0 ,cost66.0,iterations180
# m0 , b0 ,cost66.0,iterations181
# m0 , b0 ,cost66.0,iterations182
# m0 , b0 ,cost66.0,iterations183
# m0 , b0 ,cost66.0,iterations184
# m0 , b0 ,cost66.0,iterations185
# m0 , b0 ,cost66.0,iterations186
# m0 , b0 ,cost66.0,iterations187
# m0 , b0 ,cost66.0,iterations188
# m0 , b0 ,cost66.0,iterations189
# m0 , b0 ,cost66.0,iterations190
# m0 , b0 ,cost66.0,iterations191
# m0 , b0 ,cost66.0,iterations192
# m0 , b0 ,cost66.0,iterations193
# m0 , b0 ,cost66.0,iterations194
# m0 , b0 ,cost66.0,iterations195
# m0 , b0 ,cost66.0,iterations196
# m0 , b0 ,cost66.0,iterations197
# m0 , b0 ,cost66.0,iterations198
# m0 , b0 ,cost66.0,iterations199
# m0 , b0 ,cost66.0,iterations200
# m0 , b0 ,cost66.0,iterations201
# m0 , b0 ,cost66.0,iterations202
# m0 , b0 ,cost66.0,iterations203
# m0 , b0 ,cost66.0,iterations204
# m0 , b0 ,cost66.0,iterations205
# m0 , b0 ,cost66.0,iterations206
# m0 , b0 ,cost66.0,iterations207
# m0 , b0 ,cost66.0,iterations208
# m0 , b0 ,cost66.0,iterations209
# m0 , b0 ,cost66.0,iterations210
# m0 , b0 ,cost66.0,iterations211
# m0 , b0 ,cost66.0,iterations212
# m0 , b0 ,cost66.0,iterations213
# m0 , b0 ,cost66.0,iterations214
# m0 , b0 ,cost66.0,iterations215
# m0 , b0 ,cost66.0,iterations216
# m0 , b0 ,cost66.0,iterations217
# m0 , b0 ,cost66.0,iterations218
# m0 , b0 ,cost66.0,iterations219
# m0 , b0 ,cost66.0,iterations220
# m0 , b0 ,cost66.0,iterations221
# m0 , b0 ,cost66.0,iterations222
# m0 , b0 ,cost66.0,iterations223
# m0 , b0 ,cost66.0,iterations224
# m0 , b0 ,cost66.0,iterations225
# m0 , b0 ,cost66.0,iterations226
# m0 , b0 ,cost66.0,iterations227
# m0 , b0 ,cost66.0,iterations228
# m0 , b0 ,cost66.0,iterations229
# m0 , b0 ,cost66.0,iterations230
# m0 , b0 ,cost66.0,iterations231
# m0 , b0 ,cost66.0,iterations232
# m0 , b0 ,cost66.0,iterations233
# m0 , b0 ,cost66.0,iterations234
# m0 , b0 ,cost66.0,iterations235
# m0 , b0 ,cost66.0,iterations236
# m0 , b0 ,cost66.0,iterations237
# m0 , b0 ,cost66.0,iterations238
# m0 , b0 ,cost66.0,iterations239
# m0 , b0 ,cost66.0,iterations240
# m0 , b0 ,cost66.0,iterations241
# m0 , b0 ,cost66.0,iterations242
# m0 , b0 ,cost66.0,iterations243
# m0 , b0 ,cost66.0,iterations244
# m0 , b0 ,cost66.0,iterations245
# m0 , b0 ,cost66.0,iterations246
# m0 , b0 ,cost66.0,iterations247
# m0 , b0 ,cost66.0,iterations248
# m0 , b0 ,cost66.0,iterations249
# m0 , b0 ,cost66.0,iterations250
# m0 , b0 ,cost66.0,iterations251
# m0 , b0 ,cost66.0,iterations252
# m0 , b0 ,cost66.0,iterations253
# m0 , b0 ,cost66.0,iterations254
# m0 , b0 ,cost66.0,iterations255
# m0 , b0 ,cost66.0,iterations256
# m0 , b0 ,cost66.0,iterations257
# m0 , b0 ,cost66.0,iterations258
# m0 , b0 ,cost66.0,iterations259
# m0 , b0 ,cost66.0,iterations260
# m0 , b0 ,cost66.0,iterations261
# m0 , b0 ,cost66.0,iterations262
# m0 , b0 ,cost66.0,iterations263
# m0 , b0 ,cost66.0,iterations264
# m0 , b0 ,cost66.0,iterations265
# m0 , b0 ,cost66.0,iterations266
# m0 , b0 ,cost66.0,iterations267
# m0 , b0 ,cost66.0,iterations268
# m0 , b0 ,cost66.0,iterations269
# m0 , b0 ,cost66.0,iterations270
# m0 , b0 ,cost66.0,iterations271
# m0 , b0 ,cost66.0,iterations272
# m0 , b0 ,cost66.0,iterations273
# m0 , b0 ,cost66.0,iterations274
# m0 , b0 ,cost66.0,iterations275
# m0 , b0 ,cost66.0,iterations276
# m0 , b0 ,cost66.0,iterations277
# m0 , b0 ,cost66.0,iterations278
# m0 , b0 ,cost66.0,iterations279
# m0 , b0 ,cost66.0,iterations280
# m0 , b0 ,cost66.0,iterations281
# m0 , b0 ,cost66.0,iterations282
# m0 , b0 ,cost66.0,iterations283
# m0 , b0 ,cost66.0,iterations284
# m0 , b0 ,cost66.0,iterations285
# m0 , b0 ,cost66.0,iterations286
# m0 , b0 ,cost66.0,iterations287
# m0 , b0 ,cost66.0,iterations288
# m0 , b0 ,cost66.0,iterations289
# m0 , b0 ,cost66.0,iterations290
# m0 , b0 ,cost66.0,iterations291
# m0 , b0 ,cost66.0,iterations292
# m0 , b0 ,cost66.0,iterations293
# m0 , b0 ,cost66.0,iterations294
# m0 , b0 ,cost66.0,iterations295
# m0 , b0 ,cost66.0,iterations296
# m0 , b0 ,cost66.0,iterations297
# m0 , b0 ,cost66.0,iterations298
# m0 , b0 ,cost66.0,iterations299
# m0 , b0 ,cost66.0,iterations300
# m0 , b0 ,cost66.0,iterations301
# m0 , b0 ,cost66.0,iterations302
# m0 , b0 ,cost66.0,iterations303
# m0 , b0 ,cost66.0,iterations304
# m0 , b0 ,cost66.0,iterations305
# m0 , b0 ,cost66.0,iterations306
# m0 , b0 ,cost66.0,iterations307
# m0 , b0 ,cost66.0,iterations308
# m0 , b0 ,cost66.0,iterations309
# m0 , b0 ,cost66.0,iterations310
# m0 , b0 ,cost66.0,iterations311
# m0 , b0 ,cost66.0,iterations312
# m0 , b0 ,cost66.0,iterations313
# m0 , b0 ,cost66.0,iterations314
# m0 , b0 ,cost66.0,iterations315
# m0 , b0 ,cost66.0,iterations316
# m0 , b0 ,cost66.0,iterations317
# m0 , b0 ,cost66.0,iterations318
# m0 , b0 ,cost66.0,iterations319
# m0 , b0 ,cost66.0,iterations320
# m0 , b0 ,cost66.0,iterations321
# m0 , b0 ,cost66.0,iterations322
# m0 , b0 ,cost66.0,iterations323
# m0 , b0 ,cost66.0,iterations324
# m0 , b0 ,cost66.0,iterations325
# m0 , b0 ,cost66.0,iterations326
# m0 , b0 ,cost66.0,iterations327
# m0 , b0 ,cost66.0,iterations328
# m0 , b0 ,cost66.0,iterations329
# m0 , b0 ,cost66.0,iterations330
# m0 , b0 ,cost66.0,iterations331
# m0 , b0 ,cost66.0,iterations332
# m0 , b0 ,cost66.0,iterations333
# m0 , b0 ,cost66.0,iterations334
# m0 , b0 ,cost66.0,iterations335
# m0 , b0 ,cost66.0,iterations336
# m0 , b0 ,cost66.0,iterations337
# m0 , b0 ,cost66.0,iterations338
# m0 , b0 ,cost66.0,iterations339
# m0 , b0 ,cost66.0,iterations340
# m0 , b0 ,cost66.0,iterations341
# m0 , b0 ,cost66.0,iterations342
# m0 , b0 ,cost66.0,iterations343
# m0 , b0 ,cost66.0,iterations344
# m0 , b0 ,cost66.0,iterations345
# m0 , b0 ,cost66.0,iterations346
# m0 , b0 ,cost66.0,iterations347
# m0 , b0 ,cost66.0,iterations348
# m0 , b0 ,cost66.0,iterations349
# m0 , b0 ,cost66.0,iterations350
# m0 , b0 ,cost66.0,iterations351
# m0 , b0 ,cost66.0,iterations352
# m0 , b0 ,cost66.0,iterations353
# m0 , b0 ,cost66.0,iterations354
# m0 , b0 ,cost66.0,iterations355
# m0 , b0 ,cost66.0,iterations356
# m0 , b0 ,cost66.0,iterations357
# m0 , b0 ,cost66.0,iterations358
# m0 , b0 ,cost66.0,iterations359
# m0 , b0 ,cost66.0,iterations360
# m0 , b0 ,cost66.0,iterations361
# m0 , b0 ,cost66.0,iterations362
# m0 , b0 ,cost66.0,iterations363
# m0 , b0 ,cost66.0,iterations364
# m0 , b0 ,cost66.0,iterations365
# m0 , b0 ,cost66.0,iterations366
# m0 , b0 ,cost66.0,iterations367
# m0 , b0 ,cost66.0,iterations368
# m0 , b0 ,cost66.0,iterations369
# m0 , b0 ,cost66.0,iterations370
# m0 , b0 ,cost66.0,iterations371
# m0 , b0 ,cost66.0,iterations372
# m0 , b0 ,cost66.0,iterations373
# m0 , b0 ,cost66.0,iterations374
# m0 , b0 ,cost66.0,iterations375
# m0 , b0 ,cost66.0,iterations376
# m0 , b0 ,cost66.0,iterations377
# m0 , b0 ,cost66.0,iterations378
# m0 , b0 ,cost66.0,iterations379
# m0 , b0 ,cost66.0,iterations380
# m0 , b0 ,cost66.0,iterations381
# m0 , b0 ,cost66.0,iterations382
# m0 , b0 ,cost66.0,iterations383
# m0 , b0 ,cost66.0,iterations384
# m0 , b0 ,cost66.0,iterations385
# m0 , b0 ,cost66.0,iterations386
# m0 , b0 ,cost66.0,iterations387
# m0 , b0 ,cost66.0,iterations388
# m0 , b0 ,cost66.0,iterations389
# m0 , b0 ,cost66.0,iterations390
# m0 , b0 ,cost66.0,iterations391
# m0 , b0 ,cost66.0,iterations392
# m0 , b0 ,cost66.0,iterations393
# m0 , b0 ,cost66.0,iterations394
# m0 , b0 ,cost66.0,iterations395
# m0 , b0 ,cost66.0,iterations396
# m0 , b0 ,cost66.0,iterations397
# m0 , b0 ,cost66.0,iterations398
# m0 , b0 ,cost66.0,iterations399
# m0 , b0 ,cost66.0,iterations400
# m0 , b0 ,cost66.0,iterations401
# m0 , b0 ,cost66.0,iterations402
# m0 , b0 ,cost66.0,iterations403
# m0 , b0 ,cost66.0,iterations404
# m0 , b0 ,cost66.0,iterations405
# m0 , b0 ,cost66.0,iterations406
# m0 , b0 ,cost66.0,iterations407
# m0 , b0 ,cost66.0,iterations408
# m0 , b0 ,cost66.0,iterations409
# m0 , b0 ,cost66.0,iterations410
# m0 , b0 ,cost66.0,iterations411
# m0 , b0 ,cost66.0,iterations412
# m0 , b0 ,cost66.0,iterations413
# m0 , b0 ,cost66.0,iterations414
# m0 , b0 ,cost66.0,iterations415
# m0 , b0 ,cost66.0,iterations416
# m0 , b0 ,cost66.0,iterations417
# m0 , b0 ,cost66.0,iterations418
# m0 , b0 ,cost66.0,iterations419
# m0 , b0 ,cost66.0,iterations420
# m0 , b0 ,cost66.0,iterations421
# m0 , b0 ,cost66.0,iterations422
# m0 , b0 ,cost66.0,iterations423
# m0 , b0 ,cost66.0,iterations424
# m0 , b0 ,cost66.0,iterations425
# m0 , b0 ,cost66.0,iterations426
# m0 , b0 ,cost66.0,iterations427
# m0 , b0 ,cost66.0,iterations428
# m0 , b0 ,cost66.0,iterations429
# m0 , b0 ,cost66.0,iterations430
# m0 , b0 ,cost66.0,iterations431
# m0 , b0 ,cost66.0,iterations432
# m0 , b0 ,cost66.0,iterations433
# m0 , b0 ,cost66.0,iterations434
# m0 , b0 ,cost66.0,iterations435
# m0 , b0 ,cost66.0,iterations436
# m0 , b0 ,cost66.0,iterations437
# m0 , b0 ,cost66.0,iterations438
# m0 , b0 ,cost66.0,iterations439
# m0 , b0 ,cost66.0,iterations440
# m0 , b0 ,cost66.0,iterations441
# m0 , b0 ,cost66.0,iterations442
# m0 , b0 ,cost66.0,iterations443
# m0 , b0 ,cost66.0,iterations444
# m0 , b0 ,cost66.0,iterations445
# m0 , b0 ,cost66.0,iterations446
# m0 , b0 ,cost66.0,iterations447
# m0 , b0 ,cost66.0,iterations448
# m0 , b0 ,cost66.0,iterations449
# m0 , b0 ,cost66.0,iterations450
# m0 , b0 ,cost66.0,iterations451
# m0 , b0 ,cost66.0,iterations452
# m0 , b0 ,cost66.0,iterations453
# m0 , b0 ,cost66.0,iterations454
# m0 , b0 ,cost66.0,iterations455
# m0 , b0 ,cost66.0,iterations456
# m0 , b0 ,cost66.0,iterations457
# m0 , b0 ,cost66.0,iterations458
# m0 , b0 ,cost66.0,iterations459
# m0 , b0 ,cost66.0,iterations460
# m0 , b0 ,cost66.0,iterations461
# m0 , b0 ,cost66.0,iterations462
# m0 , b0 ,cost66.0,iterations463
# m0 , b0 ,cost66.0,iterations464
# m0 , b0 ,cost66.0,iterations465
# m0 , b0 ,cost66.0,iterations466
# m0 , b0 ,cost66.0,iterations467
# m0 , b0 ,cost66.0,iterations468
# m0 , b0 ,cost66.0,iterations469
# m0 , b0 ,cost66.0,iterations470
# m0 , b0 ,cost66.0,iterations471
# m0 , b0 ,cost66.0,iterations472
# m0 , b0 ,cost66.0,iterations473
# m0 , b0 ,cost66.0,iterations474
# m0 , b0 ,cost66.0,iterations475
# m0 , b0 ,cost66.0,iterations476
# m0 , b0 ,cost66.0,iterations477
# m0 , b0 ,cost66.0,iterations478
# m0 , b0 ,cost66.0,iterations479
# m0 , b0 ,cost66.0,iterations480
# m0 , b0 ,cost66.0,iterations481
# m0 , b0 ,cost66.0,iterations482
# m0 , b0 ,cost66.0,iterations483
# m0 , b0 ,cost66.0,iterations484
# m0 , b0 ,cost66.0,iterations485
# m0 , b0 ,cost66.0,iterations486
# m0 , b0 ,cost66.0,iterations487
# m0 , b0 ,cost66.0,iterations488
# m0 , b0 ,cost66.0,iterations489
# m0 , b0 ,cost66.0,iterations490
# m0 , b0 ,cost66.0,iterations491
# m0 , b0 ,cost66.0,iterations492
# m0 , b0 ,cost66.0,iterations493
# m0 , b0 ,cost66.0,iterations494
# m0 , b0 ,cost66.0,iterations495
# m0 , b0 ,cost66.0,iterations496
# m0 , b0 ,cost66.0,iterations497
# m0 , b0 ,cost66.0,iterations498
# m0 , b0 ,cost66.0,iterations499
# m0 , b0 ,cost66.0,iterations500
# m0 , b0 ,cost66.0,iterations501
# m0 , b0 ,cost66.0,iterations502
# m0 , b0 ,cost66.0,iterations503
# m0 , b0 ,cost66.0,iterations504
# m0 , b0 ,cost66.0,iterations505
# m0 , b0 ,cost66.0,iterations506
# m0 , b0 ,cost66.0,iterations507
# m0 , b0 ,cost66.0,iterations508
# m0 , b0 ,cost66.0,iterations509
# m0 , b0 ,cost66.0,iterations510
# m0 , b0 ,cost66.0,iterations511
# m0 , b0 ,cost66.0,iterations512
# m0 , b0 ,cost66.0,iterations513
# m0 , b0 ,cost66.0,iterations514
# m0 , b0 ,cost66.0,iterations515
# m0 , b0 ,cost66.0,iterations516
# m0 , b0 ,cost66.0,iterations517
# m0 , b0 ,cost66.0,iterations518
# m0 , b0 ,cost66.0,iterations519
# m0 , b0 ,cost66.0,iterations520
# m0 , b0 ,cost66.0,iterations521
# m0 , b0 ,cost66.0,iterations522
# m0 , b0 ,cost66.0,iterations523
# m0 , b0 ,cost66.0,iterations524
# m0 , b0 ,cost66.0,iterations525
# m0 , b0 ,cost66.0,iterations526
# m0 , b0 ,cost66.0,iterations527
# m0 , b0 ,cost66.0,iterations528
# m0 , b0 ,cost66.0,iterations529
# m0 , b0 ,cost66.0,iterations530
# m0 , b0 ,cost66.0,iterations531
# m0 , b0 ,cost66.0,iterations532
# m0 , b0 ,cost66.0,iterations533
# m0 , b0 ,cost66.0,iterations534
# m0 , b0 ,cost66.0,iterations535
# m0 , b0 ,cost66.0,iterations536
# m0 , b0 ,cost66.0,iterations537
# m0 , b0 ,cost66.0,iterations538
# m0 , b0 ,cost66.0,iterations539
# m0 , b0 ,cost66.0,iterations540
# m0 , b0 ,cost66.0,iterations541
# m0 , b0 ,cost66.0,iterations542
# m0 , b0 ,cost66.0,iterations543
# m0 , b0 ,cost66.0,iterations544
# m0 , b0 ,cost66.0,iterations545
# m0 , b0 ,cost66.0,iterations546
# m0 , b0 ,cost66.0,iterations547
# m0 , b0 ,cost66.0,iterations548
# m0 , b0 ,cost66.0,iterations549
# m0 , b0 ,cost66.0,iterations550
# m0 , b0 ,cost66.0,iterations551
# m0 , b0 ,cost66.0,iterations552
# m0 , b0 ,cost66.0,iterations553
# m0 , b0 ,cost66.0,iterations554
# m0 , b0 ,cost66.0,iterations555
# m0 , b0 ,cost66.0,iterations556
# m0 , b0 ,cost66.0,iterations557
# m0 , b0 ,cost66.0,iterations558
# m0 , b0 ,cost66.0,iterations559
# m0 , b0 ,cost66.0,iterations560
# m0 , b0 ,cost66.0,iterations561
# m0 , b0 ,cost66.0,iterations562
# m0 , b0 ,cost66.0,iterations563
# m0 , b0 ,cost66.0,iterations564
# m0 , b0 ,cost66.0,iterations565
# m0 , b0 ,cost66.0,iterations566
# m0 , b0 ,cost66.0,iterations567
# m0 , b0 ,cost66.0,iterations568
# m0 , b0 ,cost66.0,iterations569
# m0 , b0 ,cost66.0,iterations570
# m0 , b0 ,cost66.0,iterations571
# m0 , b0 ,cost66.0,iterations572
# m0 , b0 ,cost66.0,iterations573
# m0 , b0 ,cost66.0,iterations574
# m0 , b0 ,cost66.0,iterations575
# m0 , b0 ,cost66.0,iterations576
# m0 , b0 ,cost66.0,iterations577
# m0 , b0 ,cost66.0,iterations578
# m0 , b0 ,cost66.0,iterations579
# m0 , b0 ,cost66.0,iterations580
# m0 , b0 ,cost66.0,iterations581
# m0 , b0 ,cost66.0,iterations582
# m0 , b0 ,cost66.0,iterations583
# m0 , b0 ,cost66.0,iterations584
# m0 , b0 ,cost66.0,iterations585
# m0 , b0 ,cost66.0,iterations586
# m0 , b0 ,cost66.0,iterations587
# m0 , b0 ,cost66.0,iterations588
# m0 , b0 ,cost66.0,iterations589
# m0 , b0 ,cost66.0,iterations590
# m0 , b0 ,cost66.0,iterations591
# m0 , b0 ,cost66.0,iterations592
# m0 , b0 ,cost66.0,iterations593
# m0 , b0 ,cost66.0,iterations594
# m0 , b0 ,cost66.0,iterations595
# m0 , b0 ,cost66.0,iterations596
# m0 , b0 ,cost66.0,iterations597
# m0 , b0 ,cost66.0,iterations598
# m0 , b0 ,cost66.0,iterations599
# m0 , b0 ,cost66.0,iterations600
# m0 , b0 ,cost66.0,iterations601
# m0 , b0 ,cost66.0,iterations602
# m0 , b0 ,cost66.0,iterations603
# m0 , b0 ,cost66.0,iterations604
# m0 , b0 ,cost66.0,iterations605
# m0 , b0 ,cost66.0,iterations606
# m0 , b0 ,cost66.0,iterations607
# m0 , b0 ,cost66.0,iterations608
# m0 , b0 ,cost66.0,iterations609
# m0 , b0 ,cost66.0,iterations610
# m0 , b0 ,cost66.0,iterations611
# m0 , b0 ,cost66.0,iterations612
# m0 , b0 ,cost66.0,iterations613
# m0 , b0 ,cost66.0,iterations614
# m0 , b0 ,cost66.0,iterations615
# m0 , b0 ,cost66.0,iterations616
# m0 , b0 ,cost66.0,iterations617
# m0 , b0 ,cost66.0,iterations618
# m0 , b0 ,cost66.0,iterations619
# m0 , b0 ,cost66.0,iterations620
# m0 , b0 ,cost66.0,iterations621
# m0 , b0 ,cost66.0,iterations622
# m0 , b0 ,cost66.0,iterations623
# m0 , b0 ,cost66.0,iterations624
# m0 , b0 ,cost66.0,iterations625
# m0 , b0 ,cost66.0,iterations626
# m0 , b0 ,cost66.0,iterations627
# m0 , b0 ,cost66.0,iterations628
# m0 , b0 ,cost66.0,iterations629
# m0 , b0 ,cost66.0,iterations630
# m0 , b0 ,cost66.0,iterations631
# m0 , b0 ,cost66.0,iterations632
# m0 , b0 ,cost66.0,iterations633
# m0 , b0 ,cost66.0,iterations634
# m0 , b0 ,cost66.0,iterations635
# m0 , b0 ,cost66.0,iterations636
# m0 , b0 ,cost66.0,iterations637
# m0 , b0 ,cost66.0,iterations638
# m0 , b0 ,cost66.0,iterations639
# m0 , b0 ,cost66.0,iterations640
# m0 , b0 ,cost66.0,iterations641
# m0 , b0 ,cost66.0,iterations642
# m0 , b0 ,cost66.0,iterations643
# m0 , b0 ,cost66.0,iterations644
# m0 , b0 ,cost66.0,iterations645
# m0 , b0 ,cost66.0,iterations646
# m0 , b0 ,cost66.0,iterations647
# m0 , b0 ,cost66.0,iterations648
# m0 , b0 ,cost66.0,iterations649
# m0 , b0 ,cost66.0,iterations650
# m0 , b0 ,cost66.0,iterations651
# m0 , b0 ,cost66.0,iterations652
# m0 , b0 ,cost66.0,iterations653
# m0 , b0 ,cost66.0,iterations654
# m0 , b0 ,cost66.0,iterations655
# m0 , b0 ,cost66.0,iterations656
# m0 , b0 ,cost66.0,iterations657
# m0 , b0 ,cost66.0,iterations658
# m0 , b0 ,cost66.0,iterations659
# m0 , b0 ,cost66.0,iterations660
# m0 , b0 ,cost66.0,iterations661
# m0 , b0 ,cost66.0,iterations662
# m0 , b0 ,cost66.0,iterations663
# m0 , b0 ,cost66.0,iterations664
# m0 , b0 ,cost66.0,iterations665
# m0 , b0 ,cost66.0,iterations666
# m0 , b0 ,cost66.0,iterations667
# m0 , b0 ,cost66.0,iterations668
# m0 , b0 ,cost66.0,iterations669
# m0 , b0 ,cost66.0,iterations670
# m0 , b0 ,cost66.0,iterations671
# m0 , b0 ,cost66.0,iterations672
# m0 , b0 ,cost66.0,iterations673
# m0 , b0 ,cost66.0,iterations674
# m0 , b0 ,cost66.0,iterations675
# m0 , b0 ,cost66.0,iterations676
# m0 , b0 ,cost66.0,iterations677
# m0 , b0 ,cost66.0,iterations678
# m0 , b0 ,cost66.0,iterations679
# m0 , b0 ,cost66.0,iterations680
# m0 , b0 ,cost66.0,iterations681
# m0 , b0 ,cost66.0,iterations682
# m0 , b0 ,cost66.0,iterations683
# m0 , b0 ,cost66.0,iterations684
# m0 , b0 ,cost66.0,iterations685
# m0 , b0 ,cost66.0,iterations686
# m0 , b0 ,cost66.0,iterations687
# m0 , b0 ,cost66.0,iterations688
# m0 , b0 ,cost66.0,iterations689
# m0 , b0 ,cost66.0,iterations690
# m0 , b0 ,cost66.0,iterations691
# m0 , b0 ,cost66.0,iterations692
# m0 , b0 ,cost66.0,iterations693
# m0 , b0 ,cost66.0,iterations694
# m0 , b0 ,cost66.0,iterations695
# m0 , b0 ,cost66.0,iterations696
# m0 , b0 ,cost66.0,iterations697
# m0 , b0 ,cost66.0,iterations698
# m0 , b0 ,cost66.0,iterations699
# m0 , b0 ,cost66.0,iterations700
# m0 , b0 ,cost66.0,iterations701
# m0 , b0 ,cost66.0,iterations702
# m0 , b0 ,cost66.0,iterations703
# m0 , b0 ,cost66.0,iterations704
# m0 , b0 ,cost66.0,iterations705
# m0 , b0 ,cost66.0,iterations706
# m0 , b0 ,cost66.0,iterations707
# m0 , b0 ,cost66.0,iterations708
# m0 , b0 ,cost66.0,iterations709
# m0 , b0 ,cost66.0,iterations710
# m0 , b0 ,cost66.0,iterations711
# m0 , b0 ,cost66.0,iterations712
# m0 , b0 ,cost66.0,iterations713
# m0 , b0 ,cost66.0,iterations714
# m0 , b0 ,cost66.0,iterations715
# m0 , b0 ,cost66.0,iterations716
# m0 , b0 ,cost66.0,iterations717
# m0 , b0 ,cost66.0,iterations718
# m0 , b0 ,cost66.0,iterations719
# m0 , b0 ,cost66.0,iterations720
# m0 , b0 ,cost66.0,iterations721
# m0 , b0 ,cost66.0,iterations722
# m0 , b0 ,cost66.0,iterations723
# m0 , b0 ,cost66.0,iterations724
# m0 , b0 ,cost66.0,iterations725
# m0 , b0 ,cost66.0,iterations726
# m0 , b0 ,cost66.0,iterations727
# m0 , b0 ,cost66.0,iterations728
# m0 , b0 ,cost66.0,iterations729
# m0 , b0 ,cost66.0,iterations730
# m0 , b0 ,cost66.0,iterations731
# m0 , b0 ,cost66.0,iterations732
# m0 , b0 ,cost66.0,iterations733
# m0 , b0 ,cost66.0,iterations734
# m0 , b0 ,cost66.0,iterations735
# m0 , b0 ,cost66.0,iterations736
# m0 , b0 ,cost66.0,iterations737
# m0 , b0 ,cost66.0,iterations738
# m0 , b0 ,cost66.0,iterations739
# m0 , b0 ,cost66.0,iterations740
# m0 , b0 ,cost66.0,iterations741
# m0 , b0 ,cost66.0,iterations742
# m0 , b0 ,cost66.0,iterations743
# m0 , b0 ,cost66.0,iterations744
# m0 , b0 ,cost66.0,iterations745
# m0 , b0 ,cost66.0,iterations746
# m0 , b0 ,cost66.0,iterations747
# m0 , b0 ,cost66.0,iterations748
# m0 , b0 ,cost66.0,iterations749
# m0 , b0 ,cost66.0,iterations750
# m0 , b0 ,cost66.0,iterations751
# m0 , b0 ,cost66.0,iterations752
# m0 , b0 ,cost66.0,iterations753
# m0 , b0 ,cost66.0,iterations754
# m0 , b0 ,cost66.0,iterations755
# m0 , b0 ,cost66.0,iterations756
# m0 , b0 ,cost66.0,iterations757
# m0 , b0 ,cost66.0,iterations758
# m0 , b0 ,cost66.0,iterations759
# m0 , b0 ,cost66.0,iterations760
# m0 , b0 ,cost66.0,iterations761
# m0 , b0 ,cost66.0,iterations762
# m0 , b0 ,cost66.0,iterations763
# m0 , b0 ,cost66.0,iterations764
# m0 , b0 ,cost66.0,iterations765
# m0 , b0 ,cost66.0,iterations766
# m0 , b0 ,cost66.0,iterations767
# m0 , b0 ,cost66.0,iterations768
# m0 , b0 ,cost66.0,iterations769
# m0 , b0 ,cost66.0,iterations770
# m0 , b0 ,cost66.0,iterations771
# m0 , b0 ,cost66.0,iterations772
# m0 , b0 ,cost66.0,iterations773
# m0 , b0 ,cost66.0,iterations774
# m0 , b0 ,cost66.0,iterations775
# m0 , b0 ,cost66.0,iterations776
# m0 , b0 ,cost66.0,iterations777
# m0 , b0 ,cost66.0,iterations778
# m0 , b0 ,cost66.0,iterations779
# m0 , b0 ,cost66.0,iterations780
# m0 , b0 ,cost66.0,iterations781
# m0 , b0 ,cost66.0,iterations782
# m0 , b0 ,cost66.0,iterations783
# m0 , b0 ,cost66.0,iterations784
# m0 , b0 ,cost66.0,iterations785
# m0 , b0 ,cost66.0,iterations786
# m0 , b0 ,cost66.0,iterations787
# m0 , b0 ,cost66.0,iterations788
# m0 , b0 ,cost66.0,iterations789
# m0 , b0 ,cost66.0,iterations790
# m0 , b0 ,cost66.0,iterations791
# m0 , b0 ,cost66.0,iterations792
# m0 , b0 ,cost66.0,iterations793
# m0 , b0 ,cost66.0,iterations794
# m0 , b0 ,cost66.0,iterations795
# m0 , b0 ,cost66.0,iterations796
# m0 , b0 ,cost66.0,iterations797
# m0 , b0 ,cost66.0,iterations798
# m0 , b0 ,cost66.0,iterations799
# m0 , b0 ,cost66.0,iterations800
# m0 , b0 ,cost66.0,iterations801
# m0 , b0 ,cost66.0,iterations802
# m0 , b0 ,cost66.0,iterations803
# m0 , b0 ,cost66.0,iterations804
# m0 , b0 ,cost66.0,iterations805
# m0 , b0 ,cost66.0,iterations806
# m0 , b0 ,cost66.0,iterations807
# m0 , b0 ,cost66.0,iterations808
# m0 , b0 ,cost66.0,iterations809
# m0 , b0 ,cost66.0,iterations810
# m0 , b0 ,cost66.0,iterations811
# m0 , b0 ,cost66.0,iterations812
# m0 , b0 ,cost66.0,iterations813
# m0 , b0 ,cost66.0,iterations814
# m0 , b0 ,cost66.0,iterations815
# m0 , b0 ,cost66.0,iterations816
# m0 , b0 ,cost66.0,iterations817
# m0 , b0 ,cost66.0,iterations818
# m0 , b0 ,cost66.0,iterations819
# m0 , b0 ,cost66.0,iterations820
# m0 , b0 ,cost66.0,iterations821
# m0 , b0 ,cost66.0,iterations822
# m0 , b0 ,cost66.0,iterations823
# m0 , b0 ,cost66.0,iterations824
# m0 , b0 ,cost66.0,iterations825
# m0 , b0 ,cost66.0,iterations826
# m0 , b0 ,cost66.0,iterations827
# m0 , b0 ,cost66.0,iterations828
# m0 , b0 ,cost66.0,iterations829
# m0 , b0 ,cost66.0,iterations830
# m0 , b0 ,cost66.0,iterations831
# m0 , b0 ,cost66.0,iterations832
# m0 , b0 ,cost66.0,iterations833
# m0 , b0 ,cost66.0,iterations834
# m0 , b0 ,cost66.0,iterations835
# m0 , b0 ,cost66.0,iterations836
# m0 , b0 ,cost66.0,iterations837
# m0 , b0 ,cost66.0,iterations838
# m0 , b0 ,cost66.0,iterations839
# m0 , b0 ,cost66.0,iterations840
# m0 , b0 ,cost66.0,iterations841
# m0 , b0 ,cost66.0,iterations842
# m0 , b0 ,cost66.0,iterations843
# m0 , b0 ,cost66.0,iterations844
# m0 , b0 ,cost66.0,iterations845
# m0 , b0 ,cost66.0,iterations846
# m0 , b0 ,cost66.0,iterations847
# m0 , b0 ,cost66.0,iterations848
# m0 , b0 ,cost66.0,iterations849
# m0 , b0 ,cost66.0,iterations850
# m0 , b0 ,cost66.0,iterations851
# m0 , b0 ,cost66.0,iterations852
# m0 , b0 ,cost66.0,iterations853
# m0 , b0 ,cost66.0,iterations854
# m0 , b0 ,cost66.0,iterations855
# m0 , b0 ,cost66.0,iterations856
# m0 , b0 ,cost66.0,iterations857
# m0 , b0 ,cost66.0,iterations858
# m0 , b0 ,cost66.0,iterations859
# m0 , b0 ,cost66.0,iterations860
# m0 , b0 ,cost66.0,iterations861
# m0 , b0 ,cost66.0,iterations862
# m0 , b0 ,cost66.0,iterations863
# m0 , b0 ,cost66.0,iterations864
# m0 , b0 ,cost66.0,iterations865
# m0 , b0 ,cost66.0,iterations866
# m0 , b0 ,cost66.0,iterations867
# m0 , b0 ,cost66.0,iterations868
# m0 , b0 ,cost66.0,iterations869
# m0 , b0 ,cost66.0,iterations870
# m0 , b0 ,cost66.0,iterations871
# m0 , b0 ,cost66.0,iterations872
# m0 , b0 ,cost66.0,iterations873
# m0 , b0 ,cost66.0,iterations874
# m0 , b0 ,cost66.0,iterations875
# m0 , b0 ,cost66.0,iterations876
# m0 , b0 ,cost66.0,iterations877
# m0 , b0 ,cost66.0,iterations878
# m0 , b0 ,cost66.0,iterations879
# m0 , b0 ,cost66.0,iterations880
# m0 , b0 ,cost66.0,iterations881
# m0 , b0 ,cost66.0,iterations882
# m0 , b0 ,cost66.0,iterations883
# m0 , b0 ,cost66.0,iterations884
# m0 , b0 ,cost66.0,iterations885
# m0 , b0 ,cost66.0,iterations886
# m0 , b0 ,cost66.0,iterations887
# m0 , b0 ,cost66.0,iterations888
# m0 , b0 ,cost66.0,iterations889
# m0 , b0 ,cost66.0,iterations890
# m0 , b0 ,cost66.0,iterations891
# m0 , b0 ,cost66.0,iterations892
# m0 , b0 ,cost66.0,iterations893
# m0 , b0 ,cost66.0,iterations894
# m0 , b0 ,cost66.0,iterations895
# m0 , b0 ,cost66.0,iterations896
# m0 , b0 ,cost66.0,iterations897
# m0 , b0 ,cost66.0,iterations898
# m0 , b0 ,cost66.0,iterations899
# m0 , b0 ,cost66.0,iterations900
# m0 , b0 ,cost66.0,iterations901
# m0 , b0 ,cost66.0,iterations902
# m0 , b0 ,cost66.0,iterations903
# m0 , b0 ,cost66.0,iterations904
# m0 , b0 ,cost66.0,iterations905
# m0 , b0 ,cost66.0,iterations906
# m0 , b0 ,cost66.0,iterations907
# m0 , b0 ,cost66.0,iterations908
# m0 , b0 ,cost66.0,iterations909
# m0 , b0 ,cost66.0,iterations910
# m0 , b0 ,cost66.0,iterations911
# m0 , b0 ,cost66.0,iterations912
# m0 , b0 ,cost66.0,iterations913
# m0 , b0 ,cost66.0,iterations914
# m0 , b0 ,cost66.0,iterations915
# m0 , b0 ,cost66.0,iterations916
# m0 , b0 ,cost66.0,iterations917
# m0 , b0 ,cost66.0,iterations918
# m0 , b0 ,cost66.0,iterations919
# m0 , b0 ,cost66.0,iterations920
# m0 , b0 ,cost66.0,iterations921
# m0 , b0 ,cost66.0,iterations922
# m0 , b0 ,cost66.0,iterations923
# m0 , b0 ,cost66.0,iterations924
# m0 , b0 ,cost66.0,iterations925
# m0 , b0 ,cost66.0,iterations926
# m0 , b0 ,cost66.0,iterations927
# m0 , b0 ,cost66.0,iterations928
# m0 , b0 ,cost66.0,iterations929
# m0 , b0 ,cost66.0,iterations930
# m0 , b0 ,cost66.0,iterations931
# m0 , b0 ,cost66.0,iterations932
# m0 , b0 ,cost66.0,iterations933
# m0 , b0 ,cost66.0,iterations934
# m0 , b0 ,cost66.0,iterations935
# m0 , b0 ,cost66.0,iterations936
# m0 , b0 ,cost66.0,iterations937
# m0 , b0 ,cost66.0,iterations938
# m0 , b0 ,cost66.0,iterations939
# m0 , b0 ,cost66.0,iterations940
# m0 , b0 ,cost66.0,iterations941
# m0 , b0 ,cost66.0,iterations942
# m0 , b0 ,cost66.0,iterations943
# m0 , b0 ,cost66.0,iterations944
# m0 , b0 ,cost66.0,iterations945
# m0 , b0 ,cost66.0,iterations946
# m0 , b0 ,cost66.0,iterations947
# m0 , b0 ,cost66.0,iterations948
# m0 , b0 ,cost66.0,iterations949
# m0 , b0 ,cost66.0,iterations950
# m0 , b0 ,cost66.0,iterations951
# m0 , b0 ,cost66.0,iterations952
# m0 , b0 ,cost66.0,iterations953
# m0 , b0 ,cost66.0,iterations954
# m0 , b0 ,cost66.0,iterations955
# m0 , b0 ,cost66.0,iterations956
# m0 , b0 ,cost66.0,iterations957
# m0 , b0 ,cost66.0,iterations958
# m0 , b0 ,cost66.0,iterations959
# m0 , b0 ,cost66.0,iterations960
# m0 , b0 ,cost66.0,iterations961
# m0 , b0 ,cost66.0,iterations962
# m0 , b0 ,cost66.0,iterations963
# m0 , b0 ,cost66.0,iterations964
# m0 , b0 ,cost66.0,iterations965
# m0 , b0 ,cost66.0,iterations966
# m0 , b0 ,cost66.0,iterations967
# m0 , b0 ,cost66.0,iterations968
# m0 , b0 ,cost66.0,iterations969
# m0 , b0 ,cost66.0,iterations970
# m0 , b0 ,cost66.0,iterations971
# m0 , b0 ,cost66.0,iterations972
# m0 , b0 ,cost66.0,iterations973
# m0 , b0 ,cost66.0,iterations974
# m0 , b0 ,cost66.0,iterations975
# m0 , b0 ,cost66.0,iterations976
# m0 , b0 ,cost66.0,iterations977
# m0 , b0 ,cost66.0,iterations978
# m0 , b0 ,cost66.0,iterations979
# m0 , b0 ,cost66.0,iterations980
# m0 , b0 ,cost66.0,iterations981
# m0 , b0 ,cost66.0,iterations982
# m0 , b0 ,cost66.0,iterations983
# m0 , b0 ,cost66.0,iterations984
# m0 , b0 ,cost66.0,iterations985
# m0 , b0 ,cost66.0,iterations986
# m0 , b0 ,cost66.0,iterations987
# m0 , b0 ,cost66.0,iterations988
# m0 , b0 ,cost66.0,iterations989
# m0 , b0 ,cost66.0,iterations990
# m0 , b0 ,cost66.0,iterations991
# m0 , b0 ,cost66.0,iterations992
# m0 , b0 ,cost66.0,iterations993
# m0 , b0 ,cost66.0,iterations994
# m0 , b0 ,cost66.0,iterations995
# m0 , b0 ,cost66.0,iterations996
# m0 , b0 ,cost66.0,iterations997
# m0 , b0 ,cost66.0,iterations998
# m0 , b0 ,cost66.0,iterations999
# None
